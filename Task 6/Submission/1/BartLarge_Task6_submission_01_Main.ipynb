# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df_twitter_preds = pd.read_csv('/content/submission_part_B.csv')
df_reddit_preds  = pd.read_csv('/content/submission_part_A.csv')
df_test = pd.read_csv('/content/drive/MyDrive/SMM4H 2024/unlabeled_testing.csv')

# %%
print(len(df_twitter_preds))
print(len(df_reddit_preds))
print(len(df_test))
# Out:
# 2200
# 6000
# 8200

# %%
df_twitter_preds
# Out:
#          id   source  label
# 0     15001  twitter      1
# 1     15002  twitter      0
# 2     15003  twitter      0
# 3     15004  twitter      0
# 4     15005  twitter      1
# ...     ...      ...    ...
# 2195  17196  twitter      0
# 2196  17197  twitter      0
# 2197  17198  twitter      0
# 2198  17199  twitter      0
# 2199  17200  twitter      0
#
# [2200 rows x 3 columns]

# %%
df_reddit_preds
# Out:
#          id  source  label
# 0     13001  reddit      1
# 1     13002  reddit      1
# 2     13003  reddit      0
# 3     13004  reddit      0
# 4     13005  reddit      0
# ...     ...     ...    ...
# 5995  21196  reddit      0
# 5996  21197  reddit      0
# 5997  21198  reddit      1
# 5998  21199  reddit      0
# 5999  21200  reddit      1
#
# [6000 rows x 3 columns]

# %%
df_test
# Out:
#          id                                               text  source
# 0     13001  So first off, I *have* made an appointment wit...  reddit
# 1     13002  Per the clinic ophthalmologist I have monocula...  reddit
# 2     13003  Top 10 questions asked about cataract: https:/...  reddit
# 3     13004  Hi, everyone :-)I have had Keratoconus in 15 y...  reddit
# 4     13005  IVMED-80. Not a lot of literature on it and it...  reddit
# ...     ...                                                ...     ...
# 8195  21196  Therapist!! If you can. I know I had troubles ...  reddit
# 8196  21197  The low self-esteem is a major cause of your s...  reddit
# 8197  21198  I am 21 and am good looking, smart but also in...  reddit
# 8198  21199  You’ve really got to put in the work, I’ve bee...  reddit
# 8199  21200  I'm gonna be alone forever - I'm 22 and in sch...  reddit
#
# [8200 rows x 3 columns]

# %%
df_merged_preds = pd.concat([df_reddit_preds, df_twitter_preds], axis=0).reset_index(drop=True)
df_merged_preds
# Out:
#          id   source  label
# 0     13001   reddit      1
# 1     13002   reddit      1
# 2     13003   reddit      0
# 3     13004   reddit      0
# 4     13005   reddit      0
# ...     ...      ...    ...
# 8195  17196  twitter      0
# 8196  17197  twitter      0
# 8197  17198  twitter      0
# 8198  17199  twitter      0
# 8199  17200  twitter      0
#
# [8200 rows x 3 columns]

# %%
df_combined_preds = pd.merge(df_test, df_merged_preds, on='id', how='inner')
df_combined_preds
# Out:
#          id                                               text source_x  \
# 0     13001  So first off, I *have* made an appointment wit...   reddit
# 1     13002  Per the clinic ophthalmologist I have monocula...   reddit
# 2     13003  Top 10 questions asked about cataract: https:/...   reddit
# 3     13004  Hi, everyone :-)I have had Keratoconus in 15 y...   reddit
# 4     13005  IVMED-80. Not a lot of literature on it and it...   reddit
# ...     ...                                                ...      ...
# 8195  21196  Therapist!! If you can. I know I had troubles ...   reddit
# 8196  21197  The low self-esteem is a major cause of your s...   reddit
# 8197  21198  I am 21 and am good looking, smart but also in...   reddit
# 8198  21199  You’ve really got to put in the work, I’ve bee...   reddit
# 8199  21200  I'm gonna be alone forever - I'm 22 and in sch...   reddit
#
#      source_y  label
# 0      reddit      1
# 1      reddit      1
# 2      reddit      0
# ...

# %%
df_combined_preds['label'].value_counts()
# Out:
# label
# 1    4446
# 0    3754
# Name: count, dtype: int64

# %%
submission_task6_1 = df_combined_preds[['id','label']]
submission_task6_1
# Out:
#          id  label
# 0     13001      1
# 1     13002      1
# 2     13003      0
# 3     13004      0
# 4     13005      0
# ...     ...    ...
# 8195  21196      0
# 8196  21197      0
# 8197  21198      1
# 8198  21199      0
# 8199  21200      1
#
# [8200 rows x 2 columns]

# %%
submission_task6_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8200 entries, 0 to 8199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      8200 non-null   int64
#  1   label   8200 non-null   int64
# dtypes: int64(2)
# memory usage: 128.2 KB

# %%
submission_task6_1.to_csv('predictions_task6.tsv', sep='\t', index=False, header=True)
# !zip predictions_task6_1.zip predictions_task6.tsv
# Out:
#   adding: predictions_task6.tsv (deflated 73%)
